# %% [markdown]
# - lmplot()
# - It creates a regression line between 2 parameters and helps to visualize their linear relationship

# %%
import seaborn as sns

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn as sns
sns.lmplot(x="total_bill",y="tip",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",markers=["o","v"])

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",markers=["o","v"],palette="BuPu_r",scatter_kws={"s":100})

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",markers=["o","v"],palette="BuPu_r")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="sex",row="time",hue="smoker")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="sex",row="time",hue="smoker",height=6,palette="coolwarm")

# %%
#bin represents how many falls in data
sns.distplot(tips["total_bill"],bins=10)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#matrix plot and heatmap

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tc=tips.corr()
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tc,annot=True,cmap="GnBu",linecolor="black",linewidth=5)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tc,annot=True,cmap="plasma",linecolor="black",linewidth=5)
# Out:
# <AxesSubplot:>

# %%
iris=sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ir=iris.corr()

# %%
ir
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(ir,annot=True,cmap="plasma",linecolor="black",linewidth=5)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
d=np.random.rand(10,12)
sns.heatmap(d)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(d,annot=True)
# Out:
# <AxesSubplot:>

# %%
import numpy as np
uniform_data = np.random.rand(10,12)
sns.heatmap(uniform_data,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(uniform_data,annot=True,vmin=0,vmax=1)
# Out:
# <AxesSubplot:>

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
f = flights.pivot("month","year","passengers")
f.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
sns.heatmap(f)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>
