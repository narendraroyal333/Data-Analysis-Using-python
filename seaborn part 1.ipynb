# %% [markdown]
# # SEABORN

# %%
import seaborn as sns

# %%
sns.get_dataset_names() # shows dataset names
# Out:
# C:\Users\91918\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\91918\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
print(dir(sns))
# Out:
# ['FacetGrid', 'JointGrid', 'PairGrid', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_orig_rc_params', 'algorithms', 'axes_style', 'axisgrid', 'barplot', 'blend_palette', 'boxenplot', 'boxplot', 'categorical', 'catplot', 'choose_colorbrewer_palette', 'choose_cubehelix_palette', 'choose_dark_palette', 'choose_diverging_palette', 'choose_light_palette', 'clustermap', 'cm', 'color_palette', 'colors', 'countplot', 'crayon_palette', 'crayons', 'cubehelix_palette', 'dark_palette', 'desaturate', 'despine', 'distplot', 'distributions', 'diverging_palette', 'dogplot', 'external', 'factorplot', 'get_dataset_names', 'heatmap', 'hls_palette', 'husl_palette', 'jointplot', 'kdeplot', 'light_palette', 'lineplot', 'lmplot', 'load_dataset', 'lvplot', 'matrix', 'miscplot', 'mpl', 'mpl_palette', 'pairplot', 'palettes', 'palplot', 'plotting_context', 'pointplot', 'rcmod', 'regplot', 'regression', 'relational', 'relpl
# ...

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': (1, 1, 1, 0),
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'projecting',
#  'patch.edgecolor': 'black',
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'patch.force_edgecolor': False,
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
df1=sns.load_dataset("titanic")
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# - Built in Themes
#   - darkgrid
#   - whitegrid
#   - dark
#   - white
#   - ticks

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(0,14,100) # 100 parts between 1 and 14
for i in range(1,5):
    plt.plot(x,np.sin(x+i*0.5)*(7-i))
sns.set_style("darkgrid")    
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(0,14,100) # 100 parts between 1 and 14
for i in range(1,5):
    plt.plot(x,np.sin(x+i*0.5)*(7-i)) # x,y where y=np.sin()
sns.set_style("whitegrid")    
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(0,14,100) # 100 parts between 1 and 14
for i in range(1,5):
    plt.plot(x,np.sin(x+i*0.5)*(7-i))
sns.set_style("white")    
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(0,14,100) # 100 parts between 1 and 14
for i in range(1,5):
    plt.plot(x,np.sin(x+i*0.5)*(7-i))
sns.set_style("whitegrid")    
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace(0,14,100) # 100 parts between 1 and 14
for i in range(1,5):
    plt.plot(x,np.sin(x+i*0.5)*(7-i))
sns.set_style("ticks")    
plt.show()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Count plot

# %%
sns.countplot(x='sex',data=df)
# in total dataset number of males and female
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style("darkgrid")
sns.countplot(x='sex',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
tips=sns.load_dataset("tips")
sns.countplot(x="sex",data=tips)
sns.despine()

# %%
tips=sns.load_dataset("tips")
sns.countplot(x="sex",data=tips)
sns.set_style("ticks")
sns.despine()

# %%
sns.set_context("poster",font_scale=2) # poster,paper,notebok,talk
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#sns.set_context("poster",font_scale=2)  # as font increases we need to increase the figure size
#plt.figure(figsize=(200,50))
sns.countplot(x='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### SWARM PLOT

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.set_context("notebook",font_scale=1)
sns.swarmplot(x=tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.set_context("notebook",font_scale=1)
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",hue="size",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",hue="sex",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.swarmplot(x="time",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.swarmplot(x="time",y="tip",data=tips,order=["Dinner","Lunch"])
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
# boxplot
sns.boxplot(x='tip',y='day',data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.boxplot(x='tip',y='day',hue='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.boxplot(x='tip',y='day',data=tips)
sns.swarmplot(x='tip',y='day',data=tips,color="0.5") 
# 2 different plots in single plot
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,inner=None)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
sns.swarmplot(x="day",y="total_bill",data=tips,color="white")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",hue="sex",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### POINT PLOT

# %%
sns.pointplot(x='day',y='total_bill',hue='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.pointplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set_style("darkgrid")
sns.pointplot(x='day',y='total_bill',hue='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set_style("whitegrid")
sns.set_context("paper",font_scale=1)
sns.pointplot(x='total_bill',y='tip',hue='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='total_bill',y='day',data=tips) # based on x and y value it changes horizontally or vertically
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.barplot(x='day',y='tip',capsize=0.2,data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>
